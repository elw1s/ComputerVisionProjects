# %%
# !pip install ultralytics

from ultralytics import YOLO

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2

# %%
image = cv2.imread('/kaggle/input/traffic-detection-project/test/images/aguanambi-1095_png_jpg.rf.4d9f0370f1c09fb2a1d1666b155911e3.jpg')
image.shape

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# %%
#Need to use wandb api key for training
results = model.train(data='/kaggle/input/traffic-detection-project/data.yaml', epochs=10, imgsz=640)

# %%
from PIL import Image
import matplotlib.pyplot as plt


# Run inference on 'bus.jpg'
predict_results = model('/kaggle/input/traffic-detection-project/test/images/aguanambi-2105_png_jpg.rf.913b43f78d50d1ac51dcf3e43cc7da2b.jpg')  # results list

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    plt.figure(figsize=(15,20))
    plt.imshow(im)
    plt.show()
